# %% [markdown]
# ### Shapash Model Overview
# https://shapash.readthedocs.io/en/latest/
#
# ##### With this tutorial you:
# Understand how to create a Shapash SmartPredictor to make prediction and have local explanation in production with a simple use case.
#
# This tutorial describes the different steps from training the model to Shapash SmartPredictor deployment. A more detailed tutorial allows you to know more about the SmartPredictor Object.
#
# Contents:
#
# - Build a Regressor
# - Compile Shapash SmartExplainer
# - From Shapash SmartExplainer to SmartPredictor
# - Save Shapash Smartpredictor Object in pickle file
# - Make a prediction

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
### Divide the dataset into independent and dependent dataset
y=df['tip']
X=df[df.columns.difference(['tip'])]

# %%
X.head()
# Out:
#    day     sex  size smoker    time  total_bill
# 0  Sun  Female     2     No  Dinner       16.99
# 1  Sun    Male     3     No  Dinner       10.34
# 2  Sun    Male     3     No  Dinner       21.01
# 3  Sun    Male     2     No  Dinner       23.68
# 4  Sun  Female     4     No  Dinner       24.59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
X['day']=X['day'].cat.codes
X['sex']=X['sex'].cat.codes
X['smoker']=X['smoker'].cat.codes
X['time']=X['time'].cat.codes
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
X
# Out:
#      day  sex  size  smoker  time  total_bill
# 0      3    1     2       1     1       16.99
# 1      3    0     3       1     1       10.34
# 2      3    0     3       1     1       21.01
# 3      3    0     2       1     1       23.68
# 4      3    1     4       1     1       24.59
# 5      3    0     4       1     1       25.29
# 6      3    0     2       1     1        8.77
# 7      3    0     4       1     1       26.88
# 8      3    0     2       1     1       15.04
# 9      3    0     2       1     1       14.78
# 10     3    0     2       1     1       10.27
# 11     3    1     4       1     1       35.26
# 12     3    0     2       1     1       15.42
# 13     3    0     4       1     1       18.43
# 14     3    1     2       1     1       14.83
# 15     3    0     2       1     1       21.58
# 16     3    1     3       1     1       10.33
# 17     3    0     3       1     1       16.29
# 18     3    1     3       1     1       16.97
# 19     2    0     3       1     1       20.65
# 20     2    0     2       1     1       17.92
# 21     2    1     2       1     1       20.29
# 22     2    1     2       1     1       15.77
# 23     2    0     4       1     1       39.42
# 24     2    0     2       1     1       19.82
# 25     2    0     4       1     1       17.81
# 26     2    0     2       1     1       13.37
# 27     2    0     2       1     1       12.69
# 28     2    0     2       1     1       21.70
# 29     2    1     2       1     1       19.65
# ..   ...  ...   ...     ...   ...         ...
# 214    2    1     3       0     1       28.17
# 215    2    1     2       0     1       12.90
# 216    2    0     5       0     1       28.15
# 217    2    0     2       0     1       11.59
# 218    2    0     2       0     1        7.74
# 219    2    1     4       0     1       30.14
# 220    1    0     2       0     0       12.16
# 221    1    1     2       0     0       13.42
# 222    1    0     1       0     0        8.58
# 223    1    1     3       1     0       15.98
# 224    1    0     2       0     0       13.42
# 225    1    1     2       0     0       16.27
# 226    1    1     2       0     0       10.09
# 227    2    0     4       1     1       20.45
# 228    2    0     2       1     1       13.28
# 229    2    1     2       0     1       22.12
# 230    2    0     4       0     1       24.01
# 231    2    0     3       0     1       15.69
# 232    2    0     2       1     1       11.61
# 233    2    0     2       1     1       10.77
# 234    2    0     2       0     1       15.53
# 235    2    0     2       1     1       10.07
# 236    2    0     2       0     1       12.60
# 237    2    0     2       0     1       32.83
# 238    2    1     3       1     1       35.83
# 239    2    0     3       1     1       29.03
# 240    2    1     2       0     1       27.18
# 241    2    0     2       0     1       22.67
# 242    2    0     2       1     1       17.82
# 243    0    1     2       1     1       18.78
#
# [244 rows x 6 columns]

# %%
### Train Test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.75,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=200).fit(X_train,y_train)

# %% [markdown]
# #### Lets Understand Our Model With Shapash
# In this section, we use the SmartExplainer Object from shapash.
#
# - It allows users to understand how the model works with the specified data.
# - This object must be used only for data mining step. Shapash provides another object for deployment.

# %%
# !pip install shapash
# Out:
# Collecting shapash
#   Downloading https://files.pythonhosted.org/packages/b5/75/fd117ed9c91408d65dbb7ed9757738d0cd3cc842c78eb0c83b4256620519/shapash-1.2.0-py2.py3-none-any.whl (841kB)
# Collecting dash-table==4.11.0 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/bb/46/cc839f897cabea3f584cf59ce9d86a5ea3828e54eefe2537ba8b640a9707/dash_table-4.11.0.tar.gz (1.8MB)
# Collecting plotly==4.12.0 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/a6/66/af86e9d9bf1a3e4f2dabebeabd02a32e8ddf671a5d072b3af2b011efea99/plotly-4.12.0-py2.py3-none-any.whl (13.1MB)
# Collecting dash-renderer==1.8.3 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/72/fe/59a322edb128ad15205002c7b81e3f5e580f6791c4a100183289e05dbfcb/dash_renderer-1.8.3.tar.gz (1.0MB)
# Collecting numba==0.51.2 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/6a/8a/6f544bb1408ef57f4111b8931eff11bf13cb9edb48f152c158a06cf5164b/numba-0.51.2-cp37-cp37m-win_amd64.whl (2.2MB)
# Collecting dash-bootstrap-components==0.9.1 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/c6/1c/745bb7c0019b8feee475c64542b7f0c6bf4b7d2df36cccd8db677a2f1cc7/dash-bootstrap-components-0.9.1.tar.gz (99kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: numpy>1.18.0 in c:\users\dell\anaconda3\lib\site-packages (from shapash) (1.19.1)
# Collecting dash==1.17.0 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/69/91/ae029886dda55b93b60ac04377bcb2ab9209dd73244e3b5e513124cc6778/dash-1.17.0.tar.gz (75kB)
# Collecting dash-html-components==1.1.1 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/02/ba/bb9427c62feb25bfbaf243894eeeb4e7c67a92b426ed0575a167100e436e/dash_html_components-1.1.1.tar.gz (188kB)
# Collecting shap==0.37.0 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/55/d6/d66cd49e8b4a710844e39b669bdde4cc83c76d05f02e1e0ecd2c0a9228f8/shap-0.37.0-cp37-cp37m-win_amd64.whl (377kB)
# Collecting pandas>1.0.2 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/f1/3f/da5b5aac6c43b15d32458948725069324451831a94e386a2a29dfeac18b4/pandas-1.2.3-cp37-cp37m-win_amd64.whl (9.1MB)
# Requirement already satisfied: nbformat>4.2.0 in c:\users\dell\anaconda3\lib\site-packages (from shapash) (4.4.0)
# Collecting dash-core-components==1.13.0 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/52/48/3dd8c7bf93cff3a9dd9d360bc25c4ec0cb191acdce13375c3ff85f98e992/dash_core_components-1.13.0.tar.gz (3.5MB)
# Collecting dash-daq==0.5.0 (from shapash)
#   Downloading https://files.pythonhosted.org/packages/16/c1/9c6adfc3646990965a5b2ca073f579cc9c09d15553fcfcd83aefd1255494/dash_daq-0.5.0.tar.gz (642kB)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from plotly==4.12.0->shapash) (1.12.0)
# Collecting retrying>=1.3.3 (from plotly==4.12.0->shapash)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Collecting llvmlite<0.35,>=0.34.0.dev0 (from numba==0.51.2->shapash)
#   Downloading https://files.pythonhosted.org/packages/c5/a3/c4963b9b8bafba8cb7c266a6436e514b3a08bd300e31621ccbec7f1a8708/llvmlite-0.34.0-cp37-cp37m-win_amd64.whl (15.9MB)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from numba==0.51.2->shapash) (40.8.0)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\dell\anaconda3\lib\site-packages (from dash==1.17.0->shapash) (1.0.2)
# Collecting flask-compress (from dash==1.17.0->shapash)
#   Downloading https://files.pythonhosted.org/packages/c6/d5/69b13600230d24310b98a52da561113fc01a5c17acf77152761eef3e50f1/Flask_Compress-1.9.0-py3-none-any.whl
# Requirement already satisfied: future in c:\users\dell\anaconda3\lib\site-packages (from dash==1.17.0->shapash) (0.17.1)
# Requirement already satisfied: scipy in c:\users\dell\appdata\roaming\python\python37\site-packages (from shap==0.37.0->shapash) (1.6.2)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\dell\anaconda3\lib\site-packages (from shap==0.37.0->shapash) (4.31.1)
# Collecting slicer==0.0.3 (from shap==0.37.0->shapash)
#   Downloading https://files.pythonhosted.org/packages/02/a6/c708c5a0f338e99cfbcb6288b88794525548e4fc1b8457feec2c552a81a4/slicer-0.0.3-py3-none-any.whl
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\lib\site-packages (from shap==0.37.0->shapash) (0.23.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dell\anaconda3\lib\site-packages (from pandas>1.0.2->shapash) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dell\anaconda3\lib\site-packages (from pandas>1.0.2->shapash) (2.8.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\dell\anaconda3\lib\site-packages (from nbformat>4.2.0->shapash) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\dell\anaconda3\lib\site-packages (from nbformat>4.2.0->shapash) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\dell\anaconda3\lib\site-packages (from nbformat>4.2.0->shapash) (4.4.0)
# Requirement already satisfied: ipython-genutils in c:\users\dell\anaconda3\lib\site-packages (from nbformat>4.2.0->shapash) (0.2.0)
# Requirement already satisfied: Jinja2>=2.10 in c:\users\dell\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.17.0->shapash) (2.10)
# Requirement already satisfied: Werkzeug>=0.14 in c:\users\dell\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.17.0->shapash) (0.14.1)
# Requirement already satisfied: click>=5.1 in c:\users\dell\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.17.0->shapash) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\dell\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.17.0->shapash) (1.1.0)
# Collecting brotli (from flask-compress->dash==1.17.0->shapash)
#   Downloading https://files.pythonhosted.org/packages/f1/cf/9cebdbbcecf9a9650cc6da672afaac5a731c9c9097a0f67031a9af9ce805/Brotli-1.0.9-cp37-cp37m-win_amd64.whl (365kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->shap==0.37.0->shapash) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->shap==0.37.0->shapash) (0.16.0)
# Requirement already satisfied: decorator in c:\users\dell\anaconda3\lib\site-packages (from traitlets>=4.1->nbformat>4.2.0->shapash) (4.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>4.2.0->shapash) (0.14.11)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>4.2.0->shapash) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\dell\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>4.2.0->shapash) (1.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from Jinja2>=2.10->Flask>=1.0.2->dash==1.17.0->shapash) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>4.2.0->shapash) (3.1.0)
# Building wheels for collected packages: dash-bootstrap-components
#   Building wheel for dash-bootstrap-components (PEP 517): started
#   Building wheel for dash-bootstrap-components (PEP 517): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\56\25\46\7cbcb9c004b9acf8955609df934c94ff17fab803bb0fde8a44
# Successfully built dash-bootstrap-components
# Building wheels for collected packages: dash-table, dash-renderer, dash, dash-html-components, dash-core-components, dash-daq, retrying
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\ca\37\90\bd45dcc5d6acbe6ac53f753a8f1732ecf5270017372e389cd8
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\cf\2b\5f\0928a6d1b7ebf280f21a2e925f36d662e6ba83e00b82c6b6bf
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\e0\32\13\8a569b638a79cf80a4a721f56040d91198adec28e3bc8123fc
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\8d\01\46\78e4de185a8a4a2da8ba31da16c52170f036d4cebeeb6e07a2
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\44\d9\90\177214625a5b5f6440b24ea807550e07fbf439a495eee4dd36
#   Building wheel for dash-daq (setup.py): started
#   Building wheel for dash-daq (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\1c\9c\f7\84731716eaa9fc952cdbdd1f87df3ca9b8805c317c609efcd6
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built dash-table dash-renderer dash dash-html-components dash-core-components dash-daq retrying
# Installing collected packages: dash-table, retrying, plotly, dash-renderer, llvmlite, numba, brotli, flask-compress, dash-core-components, dash-html-components, dash, dash-bootstrap-components, slicer, pandas, shap, dash-daq, shapash
#   Found existing installation: llvmlite 0.28.0
# Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
from shapash.explainer.smart_explainer import SmartExplainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-0f595c109b8a> in <module>
# ----> 1 from shapash.explainer.smart_explainer import SmartExplainer
#
# ModuleNotFoundError: No module named 'shapash'

# %%
xpl = SmartExplainer()

# %%
xpl.compile(
    x=X_test,
    model=regressor,
   
)
# Out:
# Backend: Shap TreeExplainer

# %%
xpl

# %% [markdown]
# #### Lets Understand the results of your trained model
# Then, we can easily get a first summary of the explanation of the model results.
#
# - Here, we chose to get the 3 most contributive features for each prediction.
# - We used a wording to get features names more understandable in operationnal case.

# %%
app = xpl.run_app(title_story='Tips Dataset')
# Out:
# C:\Users\win10\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:1549: FutureWarning:
#
# Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#
# INFO:root:Your Shapash application run on http://DESKTOP-6UM7HAR:8050/
# Dash is running on http://0.0.0.0:8050/
# INFO:root:Use the method .kill() to down your app.
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
# INFO:shapash.webapp.smart_app:Dash is running on http://0.0.0.0:8050/
#  * Serving Flask app "shapash.webapp.smart_app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://0.0.0.0:8050/ (Press CTRL+C to quit)
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "GET /_dash-dependencies HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "GET /_dash-layout HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:52:53] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:53:08] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:53:55] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:05] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:06] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:06] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:06] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:13] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:14] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:14] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:14] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:15] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:16] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:16] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:16] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:20] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:20] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:20] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:21] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:21] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:22] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:22] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:22] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:24] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:29] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:30] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:30] "POST /_dash-update-component HTTP/1.1" 204 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:30] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:30] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:30] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:30] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:31] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:31] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:32] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.137.1 - - [06/Apr/2021 15:54:51] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Apr/2021 15:55:30] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:55:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:55:43] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:55:57] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:55:59] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:55:59] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:55:59] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:55:59] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:01] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:01] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:01] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:01] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:10] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:44] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:44] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:57] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:56:57] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:03] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:04] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:08] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:08] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:15] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:16] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:22] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.136 - - [06/Apr/2021 15:57:26] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
predictor = xpl.to_smartpredictor()

# %%
predictor.save('./predictor.pkl')

# %%
from shapash.utils.load_smartpredictor import load_smartpredictor
predictor_load = load_smartpredictor('./predictor.pkl')

# %% [markdown]
# #### Make a prediction with your SmartPredictor
# In order to make new predictions and summarize local explainability of your model on new datasets, you can use the method add_input of the SmartPredictor.
#
# - The add_input method is the first step to add a dataset for prediction and explainability.
# - It checks the structure of the dataset, the prediction and the contribution if specified.
# - It applies the preprocessing specified in the initialisation and reorder the features with the order used by the model. (see the documentation of this method)
# - In API mode, this method can handle dictionnaries data which can be received from a GET or a POST request.
# - Add data
# - The x input in add_input method doesn't have to be encoded, add_input applies preprocessing.

# %%
predictor_load.add_input(x=X, ypred=y)

# %%
detailed_contributions = predictor_load.detail_contributions()

# %%
detailed_contributions.head()
# Out:
#     tip       day       sex      size    smoker      time  total_bill
# 0  1.01  0.058890  0.107123 -0.021913 -0.032742 -0.005985    0.183477
# 1  1.66  0.083062 -0.058770  0.003739 -0.062743 -0.018027   -1.230111
# 2  3.50  0.084890 -0.021616 -0.005301 -0.008053  0.006988    0.428840
# 3  3.31  0.125816 -0.021922 -0.043787  0.022929  0.007135    0.074177
# 4  3.61  0.048222  0.058356 -0.053819 -0.006406 -0.006721   -0.319232

# %% [markdown]
# #### Summarize explanability of the predictions
# - You can use the summarize method to summarize your local explainability
# - This summary can be configured with modify_mask method so that you have explainability that meets your operational needs.

# %%
predictor_load.modify_mask(max_contrib=3)

# %%
explanation = predictor_load.summarize()

# %%
explanation.head()
# Out:
#     tip   feature_1 value_1 contribution_1   feature_2 value_2 contribution_2  \
# 0  1.01  total_bill   16.99       0.183477         sex     1.0       0.107123
# 1  1.66  total_bill   10.34      -1.230111         day     3.0       0.083062
# 2  3.50  total_bill   21.01        0.42884         day     3.0        0.08489
# 3  3.31         day     3.0       0.125816  total_bill   23.68       0.074177
# 4  3.61  total_bill   24.59      -0.319232         sex     1.0       0.058356
#
#   feature_3 value_3 contribution_3
# 0       day     3.0        0.05889
# 1    smoker     1.0      -0.062743
# 2       sex     0.0      -0.021616
# 3      size     2.0      -0.043787
# 4      size     4.0      -0.053819
